# %%
import pandas as pd
file_path_excel = R'E:\data\国家认同数据清理后.xlsx'
df_excel = pd.read_excel(file_path_excel)
# 创建民族、年级和政治面貌的交互表
cross_tab = pd.crosstab(index=[df_excel['民族'], df_excel['年级']], 
                        columns=df_excel['政治面貌'], 
                        margins=True,normalize=True)  # All 行和列的总和

cross_tab
# Out:
# 政治面貌           1         2         3         4       All
# 民族  年级
# 1   0   0.000000  0.000000  0.001284  0.000000  0.001284
#     1   0.119384  0.007702  0.010270  0.002567  0.139923
#     2   0.116816  0.019255  0.012837  0.002567  0.151476
#     3   0.039795  0.028241  0.007702  0.005135  0.080873
#     4   0.028241  0.014121  0.002567  0.000000  0.044929
# ...          ...       ...       ...       ...       ...
# 36  1   0.001284  0.000000  0.000000  0.000000  0.001284
# 47  2   0.001284  0.000000  0.000000  0.000000  0.001284
# 48  1   0.000000  0.001284  0.000000  0.000000  0.001284
# 97  2   0.001284  0.000000  0.000000  0.000000  0.001284
# All     0.736842  0.132221  0.110398  0.020539  1.000000
#
# [78 rows x 5 columns]

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = 1

# 筛选出特定年级的数据
df_specific_grade = df_excel[df_excel['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['会打多少分'], df_specific_grade['政治面貌'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
# chi2_grade, p_grade, dof_grade, expected_grade[:10]  # 展示期望频次的前10个结果，避免过长的输出

cross_tab
# Out:
# 26.390294602838058 0.009448085692166378
# 政治面貌           1         2         3         4       All
# 民族  年级
# 1   0   0.000000  0.000000  0.001284  0.000000  0.001284
#     1   0.119384  0.007702  0.010270  0.002567  0.139923
#     2   0.116816  0.019255  0.012837  0.002567  0.151476
#     3   0.039795  0.028241  0.007702  0.005135  0.080873
#     4   0.028241  0.014121  0.002567  0.000000  0.044929
# ...          ...       ...       ...       ...       ...
# 36  1   0.001284  0.000000  0.000000  0.000000  0.001284
# 47  2   0.001284  0.000000  0.000000  0.000000  0.001284
# 48  1   0.000000  0.001284  0.000000  0.000000  0.001284
# 97  2   0.001284  0.000000  0.000000  0.000000  0.001284
# All     0.736842  0.132221  0.110398  0.020539  1.000000
#
# [78 rows x 5 columns]

# %%
import pandas as pd
file_path_spss= R'E:\data\国家认同数据清理后.sav'
df_spss= pd.read_spss(file_path_spss)
cross_tab = pd.crosstab(index=[df_spss['会打多少分'], df_spss['年级']], 
                        columns=df_spss['政治面貌'], 
                        margins=True,normalize=True)  # All 行和列的总和

cross_tab
# Out:
# 政治面貌            党员        其他        团员        群众       All
# 会打多少分 年级
# 20~40 大一  0.000000  0.000000  0.010270  0.001284  0.011553
#       大三  0.001284  0.000000  0.002567  0.000000  0.003851
#       大二  0.001284  0.000000  0.012837  0.001284  0.015404
#       大四  0.000000  0.000000  0.001284  0.001284  0.002567
# 八十到一百 大一  0.002567  0.000000  0.091142  0.010270  0.103979
#       大三  0.008986  0.003851  0.030809  0.003851  0.047497
#       大二  0.012837  0.001284  0.066752  0.005135  0.086008
#       大四  0.010270  0.000000  0.024390  0.002567  0.037227
#       预科  0.000000  0.000000  0.001284  0.001284  0.002567
# 六十到八十 大一  0.007702  0.000000  0.151476  0.016688  0.175866
#       大三  0.033376  0.005135  0.048780  0.015404  0.102696
#       大二  0.007702  0.003851  0.110398  0.010270  0.132221
#       大四  0.007702  0.000000  0.037227  0.005135  0.050064
#       预科  0.000000  0.000000  0.008986  0.000000  0.008986
# 四十到六十 大一  0.005135  0.003851  0.032092  0.003851  0.044929
#       大三  0.010270  0.001284  0.025674  0.006418  0.043646
#       大二  0.011553  0.001284  0.043646  0.016688  0.073171
#       大四  0.005135  0.000000  0.010270  0.005135  0.020539
#       预科  0.000000  0.000000  0.005135  0.000000  0.005135
# 零到二十  大一  0.000000  0.000000  0.006418  0.001284  0.007702
#       大三  0.002567  0.000000  0.003851  0.002567  0.008986
#       大二  0.001284  0.000000  0.011553  0.000000  0.012837
#       大四  0.002567  0.000000  0.000000  0.000000  0.002567
# All       0.132221  0.020539  0.736842  0.110398  1.000000

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = '大一'

# 筛选出特定年级的数据
df_specific_grade = df_spss[df_spss['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['政治面貌'],
                                       df_specific_grade['会打多少分'],
                                       margins=True,normalize=True)

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 0.09847124851805246 1.0
# 会打多少分     20~40     八十到一百     六十到八十     四十到六十      零到二十       All
# 政治面貌
# 党员     0.000000  0.007463  0.022388  0.014925  0.000000  0.044776
# 其他     0.000000  0.000000  0.000000  0.011194  0.000000  0.011194
# 团员     0.029851  0.264925  0.440299  0.093284  0.018657  0.847015
# 群众     0.003731  0.029851  0.048507  0.011194  0.003731  0.097015
# All    0.033582  0.302239  0.511194  0.130597  0.022388  1.000000

# %%
import mytools2

# %%
mytools2.两个无序类别变量的统计分析(df_specific_grade,'政治面貌','会打多少分')
# Out:
# tau_y系数: 0.0251 极弱相关或无相关
# ----  -  --  ---  --  -
# 党员  0   2    6   4  0
# 其他  0   0    0   3  0
# 团员  8  71  118  25  5
# 群众  1   8   13   3  1
# ----  -  --  ---  --  -
# 卡方值： 26.39, p值： 0.0094,自由度:12。
# 拒绝虚无假设

# %% [markdown]
# 由于卡方检验的结果接近0，且p值大于显著性水平（通常为0.05），我们可以得出以下结论：
#
# 1、在自由度为12的情况下，实际观测频数与期望频数之间的差异不显著。
# 2、实际观测频数与期望频数之间没有显著差异，可能是因为样本量不够大或者数据分布不够集中。
# 3、在这种情况下，我们不能拒绝原假设，即实际观测频数与期望频数之间没有显著差异。
